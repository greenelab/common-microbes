# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from cm_modules import paths
# Out:
# /home/alexandra/anaconda3/envs/microbe/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
# Load dataset
# Each column is a bacterial taxon, and each row is a single sample.
# Rows are named using the format "${PROJECT_ID}_${SAMPLE_ID}"
# Each cell is a read count.
# There are ~11,800 samples in the preliminary dataset.
# sample x taxon

microbiome_data_filename = paths.RAW_MICROBIOME_DATA
microbiome_data = pd.read_csv(microbiome_data_filename, sep="\t", index_col=0, header=0)

# %%
print(microbiome_data.shape)
microbiome_data.head()
# Out:
# (11857, 1232)
#                      Bacteria Actinobacteriota Actinobacteria Bifidobacteriales Bifidobacteriaceae Bifidobacterium  \
# PRJDB5310_DRR077057                                                311
# PRJDB5310_DRR077058                                                243
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                698
# PRJDB5310_DRR077061                                                 39
#
#                      Bacteria Bacteroidota Bacteroidia Bacteroidales Bacteroidaceae Bacteroides  \
# PRJDB5310_DRR077057                                                423
# PRJDB5310_DRR077058                                                313
# PRJDB5310_DRR077059                                                255
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                335
#
#                      Bacteria Actinobacteriota Coriobacteriia Coriobacteriales Coriobacteriaceae Collinsella  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                167
# PRJDB5310_DRR077061                                                 64
#
#                      Bacteria Firmicutes Clostridia Lachnospirales Lachnospiraceae Agathobacter  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                196
# PRJDB5310_DRR077060                                                159
# PRJDB5310_DRR077061                                                 96
#
#                      Bacteria Firmicutes Negativicutes Veillonellales-Selenomonadales Selenomonadaceae Megamonas  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                 61
#
#                      Bacteria Firmicutes Clostridia Lachnospirales Lachnospiraceae Blautia  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                 13
# PRJDB5310_DRR077059                                                477
# PRJDB5310_DRR077060                                                158
# PRJDB5310_DRR077061                                                189
#
#                      Bacteria Firmicutes Clostridia Oscillospirales Ruminococcaceae Faecalibacterium  \
# PRJDB5310_DRR077057                                                429
# PRJDB5310_DRR077058                                                239
# PRJDB5310_DRR077059                                                297
# PRJDB5310_DRR077060                                                151
# PRJDB5310_DRR077061                                                104
#
#                      Bacteria Firmicutes Clostridia Lachnospirales Lachnospiraceae Anaerostipes  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                 51
# PRJDB5310_DRR077060                                                 23
# PRJDB5310_DRR077061                                                 68
#
#                      Bacteria Bacteroidota Bacteroidia Bacteroidales Prevotellaceae Prevotella  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Firmicutes Bacilli Lactobacillales Streptococcaceae Streptococcus  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                127
# PRJDB5310_DRR077061                                                 23
#
#                                                                 ...                                              \
# PRJDB5310_DRR077057                                             ...
# PRJDB5310_DRR077058                                             ...
# PRJDB5310_DRR077059                                             ...
# PRJDB5310_DRR077060                                             ...
# PRJDB5310_DRR077061                                             ...
#
#                      Bacteria Actinobacteriota Acidimicrobiia Microtrichales Ilumatobacteraceae NA  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Verrucomicrobiota Verrucomicrobiae Pedosphaerales Pedosphaeraceae ADurb.Bin063-1  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Proteobacteria Alphaproteobacteria Caulobacterales Caulobacteraceae PMMR1  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Bacteroidota Bacteroidia Flavobacteriales Cryomorphaceae NA  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Bacteroidota Bacteroidia Flavobacteriales Flavobacteriaceae Pseudofulvibacter  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Proteobacteria Alphaproteobacteria Rickettsiales Rickettsiaceae NA  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Bacteroidota Bacteroidia Flavobacteriales Flavobacteriaceae Gelidibacter  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Proteobacteria Gammaproteobacteria Burkholderiales Comamonadaceae Ideonella  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Proteobacteria Alphaproteobacteria Rhizobiales Xanthobacteraceae Rhodoplanes  \
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
#                      Bacteria Proteobacteria Alphaproteobacteria Sphingomonadales Sphingomonadaceae Rhizorhapis
# PRJDB5310_DRR077057                                                  0
# PRJDB5310_DRR077058                                                  0
# PRJDB5310_DRR077059                                                  0
# PRJDB5310_DRR077060                                                  0
# PRJDB5310_DRR077061                                                  0
#
# [5 rows x 1232 columns]

# %%
# How sparse is this data matrix?
# How many 0s
num_zeros = (microbiome_data == 0).sum().sum()
total = microbiome_data.shape[0] * microbiome_data.shape[1]
num_zeros / total
# Out:
# 0.9784085569486598

# %%
# Number of 0's per taxa
zero_per_taxa = sns.displot((microbiome_data == 0).sum())
plt.show(zero_per_taxa)

# %%
# Plot distribution of abundances per taxa
boxplot = np.log10(1 + microbiome_data).boxplot(rot=90, fontsize=5)
# Out:
# /home/alexandra/anaconda3/envs/microbe/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
plt.show(boxplot)
plt.set_title("log10 abundance per taxa")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-535883405f92> in <module>
#       1 plt.show(boxplot)
# ----> 2 plt.set_title('log10 abundance per taxa')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'

# %%
# What is the range of values per feature (taxa)
microbiome_data.min()

# %%
# What is the range of values per feature (taxa)
microbiome_data.max()
